# %% [markdown]
# **This Jupyter Notebook (`live_object_detection.ipynb`) demonstrates live object detection using a pre-trained YOLO (You Only Look Once)**
#
# - It captures video from your webcam, processes each frame with the YOLO model, and displays the results with bounding boxes and class labels overlaid on the video feed.

# %% [markdown]
# -----------------

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.76-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in c:\users\shuhul\anaconda3\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\shuhul\anaconda3\lib\site-packages (from ultralytics) (3.10.0)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\shuhul\anaconda3\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\shuhul\anaconda3\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\shuhul\anaconda3\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\shuhul\anaconda3\lib\site-packages (from ultralytics) (1.15.1)
# Collecting torch>=1.8.0 (from ultralytics)
#   Using cached torch-2.6.0-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.21.0-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\shuhul\anaconda3\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\users\shuhul\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\shuhul\anaconda3\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\shuhul\anaconda3\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\shuhul\anaconda3\lib\site-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shuhul\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\shuhul\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shuhul\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shuhul\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\shuhul\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shuhul\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shuhul\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shuhul\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shuhul\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shuhul\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shuhul\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shuhul\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shuhul\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in c:\users\shuhul\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\shuhul\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in c:\users\shuhul\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\shuhul\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\shuhul\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.12.0)
# Requirement already satisfied: setuptools in c:\users\shuhul\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (75.8.0)
# Collecting sympy==1.13.1 (from torch>=1.8.0->ultralytics)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\shuhul\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\shuhul\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\shuhul\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shuhul\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.76-py3-none-any.whl (915 kB)
#    ---------------------------------------- 0.0/915.2 kB ? eta -:--:--
#    --------------------------------------- 915.2/915.2 kB 13.9 MB/s eta 0:00:00
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# Using cached torch-2.6.0-cp312-cp312-win_amd64.whl (204.1 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached torchvision-0.21.0-cp312-cp312-win_amd64.whl (1.6 MB)
# Using cached ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: sympy, opencv-python, torch, ultralytics-thop, torchvision, ultralytics
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
# Successfully installed opencv-python-4.11.0.86 sympy-1.13.1 torch-2.6.0 torchvision-0.21.0 ultralytics-8.3.76 ultralytics-thop-2.0.14
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO
import cv2
import math
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolo-Weights\yolov8n.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:01<00:00, 6.18MB/s]
# 0: 480x640 1 person, 198.1ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 17.2ms preprocess, 198.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 143.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 7.4ms preprocess, 143.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 147.9ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 3.3ms preprocess, 147.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 37.1ms preprocess, 207.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 4.3ms preprocess, 95.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.9ms preprocess, 76.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 66.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.6ms preprocess, 67.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.2ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.6ms preprocess, 64.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.7ms preprocess, 62.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.2ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.5ms preprocess, 63.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 66.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 1.6ms preprocess, 66.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 61.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 1.2ms preprocess, 61.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.8ms preprocess, 64.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.7ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 69.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 2.0ms preprocess, 69.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 65.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.8ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 64.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.28
# Class name --> toothbrush
# Speed: 2.0ms preprocess, 64.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 toothbrushs, 63.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.42
# Class name --> toothbrush
# Confidence ---> 0.34
# Class name --> toothbrush
# Confidence ---> 0.29
# Class name --> toothbrush
# Confidence ---> 0.29
# Class name --> toothbrush
# Speed: 1.3ms preprocess, 63.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.3ms preprocess, 71.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 toothbrushs, 61.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.42
# Class name --> toothbrush
# Confidence ---> 0.28
# Class name --> toothbrush
# Confidence ---> 0.26
# Class name --> toothbrush
# Confidence ---> 0.26
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 61.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 62.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.31
# Class name --> toothbrush
# Speed: 1.8ms preprocess, 62.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 63.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.34
# Class name --> toothbrush
# Confidence ---> 0.27
# Class name --> toothbrush
# Speed: 1.7ms preprocess, 63.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 61.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.34
# Class name --> toothbrush
# Confidence ---> 0.33
# Class name --> toothbrush
# Speed: 1.3ms preprocess, 61.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 64.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.27
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 64.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 66.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.45
# Class name --> toothbrush
# Confidence ---> 0.3
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 64.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.49
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 64.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 65.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.46
# Class name --> toothbrush
# Speed: 2.1ms preprocess, 65.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 69.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.4
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 69.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 76.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.3
# Class name --> toothbrush
# Speed: 1.4ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 67.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.49
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 67.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 62.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.62
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 62.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 65.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.6
# Class name --> toothbrush
# Speed: 1.9ms preprocess, 65.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 64.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.52
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 64.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 64.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.73
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 62.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.71
# Class name --> toothbrush
# Speed: 1.4ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 87.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.75
# Class name --> toothbrush
# Speed: 2.0ms preprocess, 87.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 94.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.78
# Class name --> toothbrush
# Speed: 1.9ms preprocess, 94.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 81.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.59
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 81.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 71.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.66
# Class name --> toothbrush
# Confidence ---> 0.29
# Class name --> toothbrush
# Speed: 1.7ms preprocess, 71.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 63.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.68
# Class name --> toothbrush
# Confidence ---> 0.29
# Class name --> toothbrush
# Speed: 1.9ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 toothbrushs, 63.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.73
# Class name --> toothbrush
# Confidence ---> 0.35
# Class name --> toothbrush
# Confidence ---> 0.27
# Class name --> toothbrush
# Speed: 1.4ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 62.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.66
# Class name --> toothbrush
# Speed: 1.8ms preprocess, 62.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 64.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.44
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 64.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 62.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.59
# Class name --> toothbrush
# Speed: 1.2ms preprocess, 62.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 toothbrushs, 64.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.65
# Class name --> toothbrush
# Confidence ---> 0.39
# Class name --> toothbrush
# Confidence ---> 0.27
# Class name --> toothbrush
# Speed: 1.7ms preprocess, 64.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 toothbrushs, 64.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.47
# Class name --> toothbrush
# Confidence ---> 0.44
# Class name --> toothbrush
# Confidence ---> 0.4
# Class name --> toothbrush
# Confidence ---> 0.3
# Class name --> toothbrush
# Speed: 1.4ms preprocess, 64.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 toothbrushs, 68.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.47
# Class name --> toothbrush
# Confidence ---> 0.44
# Class name --> toothbrush
# Confidence ---> 0.4
# Class name --> toothbrush
# Confidence ---> 0.3
# Class name --> toothbrush
# Speed: 1.8ms preprocess, 68.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 58.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.26
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 toothbrushs, 65.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.48
# Class name --> toothbrush
# Confidence ---> 0.37
# Class name --> toothbrush
# Confidence ---> 0.36
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 65.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 63.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.29
# Class name --> toothbrush
# Speed: 1.4ms preprocess, 63.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.7ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.2ms preprocess, 69.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.8ms preprocess, 68.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.5ms preprocess, 66.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.4ms preprocess, 65.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 69.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.3
# Class name --> toothbrush
# Confidence ---> 0.3
# Class name --> toothbrush
# Speed: 2.0ms preprocess, 69.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 65.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.3
# Class name --> toothbrush
# Confidence ---> 0.3
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 65.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 67.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.47
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 67.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 62.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.46
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 62.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.8ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 66.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.28
# Class name --> toothbrush
# Speed: 1.4ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.8ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.6ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 62.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.26
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 62.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 70.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.5ms preprocess, 70.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.1ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 toothbrush, 66.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.27
# Class name --> cup
# Confidence ---> 0.26
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 66.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 toothbrushs, 67.2ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.41
# Class name --> toothbrush
# Confidence ---> 0.41
# Class name --> toothbrush
# Confidence ---> 0.35
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 67.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 64.1ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.32
# Class name --> toothbrush
# Confidence ---> 0.28
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 64.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 toothbrushs, 67.3ms
# Confidence ---> 0.76
# Class name --> toothbrush
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.66
# Class name --> toothbrush
# Confidence ---> 0.36
# Class name --> toothbrush
# Confidence ---> 0.33
# Class name --> toothbrush
# Confidence ---> 0.31
# Class name --> toothbrush
# Speed: 1.4ms preprocess, 67.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 toothbrushs, 64.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.47
# Class name --> toothbrush
# Confidence ---> 0.38
# Class name --> toothbrush
# Confidence ---> 0.29
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 61.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.4
# Class name --> toothbrush
# Speed: 1.4ms preprocess, 61.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 toothbrushs, 69.5ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.44
# Class name --> toothbrush
# Confidence ---> 0.43
# Class name --> toothbrush
# Confidence ---> 0.27
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 69.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 62.3ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.53
# Class name --> toothbrush
# Confidence ---> 0.44
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 62.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 67.7ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.39
# Class name --> toothbrush
# Speed: 1.8ms preprocess, 67.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 70.6ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.56
# Class name --> toothbrush
# Speed: 2.3ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 73.3ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.72
# Class name --> toothbrush
# Confidence ---> 0.3
# Class name --> toothbrush
# Speed: 2.1ms preprocess, 73.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 83.3ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.67
# Class name --> toothbrush
# Speed: 1.8ms preprocess, 83.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 90.2ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.59
# Class name --> toothbrush
# Speed: 1.9ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 89.9ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.46
# Class name --> toothbrush
# Confidence ---> 0.39
# Class name --> toothbrush
# Speed: 2.3ms preprocess, 89.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 67.6ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.42
# Class name --> toothbrush
# Confidence ---> 0.26
# Class name --> toothbrush
# Speed: 1.7ms preprocess, 67.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.3ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.4ms preprocess, 65.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.2ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.3ms preprocess, 72.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 72.1ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.39
# Class name --> toothbrush
# Confidence ---> 0.26
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 72.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 toothbrushs, 70.1ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.47
# Class name --> toothbrush
# Confidence ---> 0.35
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 70.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 toothbrushs, 69.1ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.4
# Class name --> toothbrush
# Confidence ---> 0.38
# Class name --> toothbrush
# Confidence ---> 0.36
# Class name --> toothbrush
# Confidence ---> 0.27
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 69.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.8ms
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.3ms preprocess, 72.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 75.7ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.43
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 75.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 71.1ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.7ms preprocess, 71.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 toothbrush, 72.6ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> toothbrush
# Speed: 2.7ms preprocess, 72.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 toothbrush, 70.3ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.28
# Class name --> toothbrush
# Speed: 2.6ms preprocess, 70.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.2ms preprocess, 68.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.1ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.3ms preprocess, 61.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 66.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.4ms preprocess, 66.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 71.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.29
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 71.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.5ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.4ms preprocess, 61.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 64.7ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.32
# Class name --> toothbrush
# Speed: 1.2ms preprocess, 64.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 63.4ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.7ms preprocess, 63.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 toothbrush, 62.9ms
# Confidence ---> 0.45
# Class name --> toothbrush
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.3ms preprocess, 62.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.7ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.0ms preprocess, 68.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.7ms preprocess, 77.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.6ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.6ms preprocess, 82.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.7ms preprocess, 88.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.8ms preprocess, 83.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.8ms preprocess, 78.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.4ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.8ms preprocess, 78.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.6ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.4ms preprocess, 75.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.4ms preprocess, 71.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.5ms preprocess, 77.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 76.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.26
# Class name --> cup
# Speed: 2.2ms preprocess, 76.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 75.5ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.29
# Class name --> cup
# Speed: 1.8ms preprocess, 75.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.9ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.4ms preprocess, 68.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.6ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.0ms preprocess, 70.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.5ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.5ms preprocess, 75.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.4ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.7ms preprocess, 68.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.7ms
# Confidence ---> 0.73
# Class name --> person
# Speed: 2.3ms preprocess, 68.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.1ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.4ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 63.0ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.46
# Class name --> chair
# Speed: 1.9ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 73.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.37
# Class name --> chair
# Speed: 1.5ms preprocess, 73.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 89.9ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.48
# Class name --> chair
# Speed: 1.9ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 86.1ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.47
# Class name --> chair
# Speed: 1.6ms preprocess, 86.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 98.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.48
# Class name --> chair
# Speed: 6.7ms preprocess, 98.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.6ms preprocess, 65.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 63.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 1.4ms preprocess, 63.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 76.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.62
# Class name --> chair
# Speed: 1.4ms preprocess, 76.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 65.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.33
# Class name --> chair
# Speed: 1.4ms preprocess, 65.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 74.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.39
# Class name --> chair
# Speed: 1.8ms preprocess, 74.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 68.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.36
# Class name --> chair
# Speed: 1.6ms preprocess, 68.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 71.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.57
# Class name --> chair
# Speed: 2.2ms preprocess, 71.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.1ms preprocess, 78.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 70.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.69
# Class name --> chair
# Speed: 1.4ms preprocess, 70.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 66.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.62
# Class name --> chair
# Speed: 1.6ms preprocess, 66.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 67.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.59
# Class name --> chair
# Speed: 1.4ms preprocess, 67.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 71.8ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.7
# Class name --> chair
# Speed: 1.4ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 75.2ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.65
# Class name --> chair
# Speed: 1.5ms preprocess, 75.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 64.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.76
# Class name --> chair
# Speed: 1.3ms preprocess, 64.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 72.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.76
# Class name --> chair
# Speed: 1.7ms preprocess, 72.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 76.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.56
# Class name --> chair
# Speed: 1.7ms preprocess, 76.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 65.4ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.43
# Class name --> chair
# Speed: 1.4ms preprocess, 65.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 69.3ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.55
# Class name --> chair
# Speed: 1.6ms preprocess, 69.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 69.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.51
# Class name --> chair
# Speed: 2.2ms preprocess, 69.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 76.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.67
# Class name --> chair
# Speed: 1.5ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 69.8ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.55
# Class name --> chair
# Speed: 2.1ms preprocess, 69.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 72.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.8ms preprocess, 72.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 74.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.34
# Class name --> chair
# Speed: 1.8ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.5ms preprocess, 70.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.5ms preprocess, 70.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 69.9ms
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.9ms preprocess, 69.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 73.3ms
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.3ms preprocess, 73.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.1ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 2.0ms preprocess, 78.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 71.8ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.59
# Class name --> cell phone
# Speed: 1.6ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.0ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 2.2ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 72.9ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.49
# Class name --> cell phone
# Speed: 2.0ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 70.1ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.32
# Class name --> toothbrush
# Speed: 1.9ms preprocess, 70.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 toothbrush, 65.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.71
# Class name --> cell phone
# Confidence ---> 0.41
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 65.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 toothbrush, 72.5ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.42
# Class name --> cell phone
# Confidence ---> 0.34
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 72.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 toothbrush, 69.8ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.41
# Class name --> toothbrush
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 2.5ms preprocess, 69.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.7ms
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.7ms preprocess, 68.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 71.4ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.48
# Class name --> cell phone
# Speed: 1.4ms preprocess, 71.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 73.4ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.32
# Class name --> cell phone
# Speed: 1.9ms preprocess, 73.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.3ms
# Confidence ---> 0.66
# Class name --> person
# Speed: 1.4ms preprocess, 70.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 75.7ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.39
# Class name --> cell phone
# Speed: 2.0ms preprocess, 75.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 72.4ms
# Confidence ---> 0.65
# Class name --> cell phone
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.6ms preprocess, 72.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 63.7ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.51
# Class name --> cell phone
# Speed: 1.7ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 61.2ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.51
# Class name --> cell phone
# Speed: 1.3ms preprocess, 61.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 68.4ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.51
# Class name --> cell phone
# Speed: 1.7ms preprocess, 68.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 66.7ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.53
# Class name --> cell phone
# Speed: 1.2ms preprocess, 66.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 63.3ms
# Confidence ---> 0.72
# Class name --> cell phone
# Confidence ---> 0.67
# Class name --> person
# Speed: 1.6ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 62.3ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.6
# Class name --> cell phone
# Speed: 1.4ms preprocess, 62.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 70.3ms
# Confidence ---> 0.77
# Class name --> cell phone
# Confidence ---> 0.72
# Class name --> person
# Speed: 2.5ms preprocess, 70.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 69.6ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.55
# Class name --> cell phone
# Speed: 1.9ms preprocess, 69.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 72.6ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.45
# Class name --> cell phone
# Speed: 1.7ms preprocess, 72.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 72.1ms
# Confidence ---> 0.69
# Class name --> cell phone
# Confidence ---> 0.59
# Class name --> person
# Speed: 1.4ms preprocess, 72.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 75.1ms
# Confidence ---> 0.77
# Class name --> cell phone
# Confidence ---> 0.68
# Class name --> person
# Speed: 2.1ms preprocess, 75.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 76.3ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.44
# Class name --> cell phone
# Speed: 1.6ms preprocess, 76.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 77.4ms
# Confidence ---> 0.6
# Class name --> cell phone
# Confidence ---> 0.59
# Class name --> person
# Speed: 1.6ms preprocess, 77.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.3ms
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.6ms preprocess, 75.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 69.8ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.51
# Class name --> cell phone
# Speed: 1.8ms preprocess, 69.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.4ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.9ms preprocess, 69.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.5ms preprocess, 74.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 69.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.2ms preprocess, 81.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.8ms preprocess, 90.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.1ms preprocess, 87.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 83.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.7ms preprocess, 82.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 82.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.5ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.7ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.4ms preprocess, 79.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.2ms preprocess, 80.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.5ms preprocess, 81.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.1ms preprocess, 81.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.6ms preprocess, 85.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 89.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.7ms preprocess, 67.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.8ms preprocess, 70.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 wine glasss, 71.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.38
# Class name --> wine glass
# Confidence ---> 0.32
# Class name --> wine glass
# Speed: 2.3ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 68.3ms
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.3
# Class name --> cup
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.6ms preprocess, 68.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 70.8ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.53
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.9ms preprocess, 70.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 68.3ms
# Confidence ---> 0.74
# Class name --> bottle
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.45
# Class name --> bottle
# Speed: 2.0ms preprocess, 68.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 62.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.72
# Class name --> bottle
# Speed: 1.5ms preprocess, 62.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 63.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.34
# Class name --> bottle
# Speed: 2.8ms preprocess, 63.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 66.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.81
# Class name --> bottle
# Speed: 1.4ms preprocess, 66.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 71.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.68
# Class name --> bottle
# Speed: 1.6ms preprocess, 71.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 67.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.74
# Class name --> bottle
# Speed: 1.9ms preprocess, 67.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 67.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.66
# Class name --> bottle
# Speed: 1.4ms preprocess, 67.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 72.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.81
# Class name --> bottle
# Speed: 1.9ms preprocess, 72.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 64.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.64
# Class name --> bottle
# Speed: 1.4ms preprocess, 64.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 69.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.49
# Class name --> bottle
# Speed: 1.3ms preprocess, 69.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 70.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.81
# Class name --> bottle
# Speed: 1.7ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 69.4ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.69
# Class name --> bottle
# Speed: 1.9ms preprocess, 69.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 72.2ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.72
# Class name --> bottle
# Speed: 1.8ms preprocess, 72.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 61.9ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.54
# Class name --> bottle
# Speed: 1.4ms preprocess, 61.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 71.6ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.72
# Class name --> bottle
# Speed: 1.4ms preprocess, 71.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 71.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.57
# Class name --> bottle
# Speed: 1.6ms preprocess, 71.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 70.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.77
# Class name --> bottle
# Speed: 1.7ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 71.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.82
# Class name --> bottle
# Speed: 1.7ms preprocess, 71.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
#
# 0: 480x640 1 person, 72.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.5ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.6ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.1ms preprocess, 74.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.5ms preprocess, 74.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.3ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 3.0ms preprocess, 73.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.4ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.1ms preprocess, 77.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.5ms preprocess, 79.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.5ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.9ms preprocess, 70.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.8ms preprocess, 70.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.7ms preprocess, 72.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.2ms preprocess, 78.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.7ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.0ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.5ms preprocess, 72.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.8ms preprocess, 79.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.5ms preprocess, 87.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.0ms preprocess, 93.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.8ms preprocess, 94.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.0ms preprocess, 79.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.9ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.7ms preprocess, 75.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.7ms preprocess, 71.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.4ms preprocess, 72.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 8.3ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.5ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.3ms preprocess, 89.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 82.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.6ms preprocess, 87.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.9ms preprocess, 79.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.7ms preprocess, 78.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.7ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.7ms preprocess, 74.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.5ms preprocess, 69.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.2ms preprocess, 71.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.9ms preprocess, 75.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.9ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.1ms preprocess, 81.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.4ms preprocess, 76.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.9ms preprocess, 81.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.1ms preprocess, 71.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.8ms preprocess, 65.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.8ms preprocess, 67.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.4ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.7ms preprocess, 87.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.9ms preprocess, 94.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.5ms preprocess, 94.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.5ms preprocess, 85.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.9ms preprocess, 84.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.2ms preprocess, 86.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.9ms preprocess, 94.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.8ms preprocess, 81.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.6ms preprocess, 79.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.8ms preprocess, 91.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.8ms preprocess, 87.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.6ms preprocess, 88.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.5ms preprocess, 87.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.7ms preprocess, 79.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.6ms preprocess, 91.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.6ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.8ms preprocess, 78.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.5ms preprocess, 74.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.7ms preprocess, 70.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 73.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.2ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.5ms preprocess, 71.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.8ms preprocess, 81.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.5ms preprocess, 75.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.1ms preprocess, 69.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.9ms preprocess, 69.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.7ms preprocess, 64.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.9ms preprocess, 71.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.4ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.5ms preprocess, 76.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.7ms preprocess, 75.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.6ms preprocess, 72.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 103.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.7ms preprocess, 131.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.1ms preprocess, 135.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.2ms preprocess, 125.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.4ms preprocess, 125.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.9ms preprocess, 135.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.1ms preprocess, 144.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.7ms preprocess, 126.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 139.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.3ms preprocess, 139.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 134.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.7ms preprocess, 134.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.6ms preprocess, 128.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.1ms preprocess, 131.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.3ms preprocess, 132.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.9ms preprocess, 132.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.5ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.6ms preprocess, 129.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.5ms preprocess, 124.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.2ms preprocess, 126.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 143.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.9ms preprocess, 143.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.0ms preprocess, 123.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.1ms preprocess, 131.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.3ms preprocess, 124.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.5ms preprocess, 125.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# KeyboardInterrupt
